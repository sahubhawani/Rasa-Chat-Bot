# %%
import pandas as pd

# %%
df = pd.read_csv('list_of_cities_and_towns_in_india-834j.csv')

# %%
df
# Out:
#                                                    S.No Name of City  \
# 0                                                     1       Mumbai
# 1                                                     2        Delhi
# 2                                                     3    Bengaluru
# 3                                                     4    Ahmedabad
# 4                                                     5    Hyderabad
# ...                                                 ...          ...
# 1212                                               1213        Warud
# 1213                                               1214     Asarganj
# 1214                                               1215       Sarsod
# 1215                                                NaN          NaN
# 1216  For more information, kindly visit :  www.down...          NaN
#
#             State                                  Type Population (2011)  \
# ...

# %%
df[df['Name of City'].notnull()]['Name of City'].to_csv('CityList.txt', index = False)
# Out:
# /usr/local/Cellar/ipython/7.8.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
df[df['Name of City'].isin(['Kolkata'])]
# Out:
#   S.No Name of City        State                                 Type  \
# 6    7      Kolkata  West Bengal  Municipal Corporation / Corporation
#
#   Population (2011) Population class  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 6         44,86,679          Class I         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10
# 6         NaN          NaN

# %%
df2[df2['City'].isin(['Kolkata'])]
# Out:
#       City
# 5  Kolkata

# %%
df2 = pd.read_csv('ChatBot/data/lookup_tables/supported_cities.txt', header = None)

# %%
df2.columns = ['City']
df2['City'] = df2['City'].str.strip()
df2
# Out:
#                  City
# 0           Ahmedabad
# 1           Bangalore
# 2           Bengaluru
# 3             Chennai
# 4               Delhi
# ..                ...
# 100  Vasai-Virar City
# 101        Vijayawada
# 102     Visakhapatnam
# 103           Vellore
# 104          Warangal
#
# [105 rows x 1 columns]

# %%
df[~(df['Name of City'].isin(df2['City']))]['Name of City']
# Out:
# 15                 Thane
# 26               Patiala
# 28      Kalyan-Dombivali
# 29           Vasai-Virar
# 36             Allahabad
#               ...
# 1212               Warud
# 1213            Asarganj
# 1214              Sarsod
# 1215                 NaN
# 1216                 NaN
# Name: Name of City, Length: 1128, dtype: object

# %%
df[~(df['Name of City'].isin(df2['City']))]['Name of City'].to_csv('UnCityList.txt', index = False)
# Out:
# /usr/local/Cellar/ipython/7.8.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
